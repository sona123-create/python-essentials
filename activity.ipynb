# %% [markdown]
# <a href="https://colab.research.google.com/github/sona123-create/python-essentials/blob/main/activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Activity 3 : 14 July 2027

# %%
student_details = [{"Roll_Number" :1,
                    "Name":"amal",
                    "Marks_in_Python" : 50,
                "Marks_in-Data_Science" : 38,
                "Marks_in_Mathematics" : 42},

                   {"Roll_Number" :2,
                    "Name":"avani",
                    "Marks_in_Python" : 50,
                "Marks_in-Data_Science" : 50,
                "Marks_in_Mathematics" : 50},

                   {"Roll_Number" :3,
                    "Name":"fathima",
                    "Marks_in_Python" : 25,
                "Marks_in-Data_Science" : 42,
                "Marks_in_Mathematics" : 40}
]

#display all students
print(student_details)

#search student by roll number
roll_number = int(input("enter the roll number"))
for roll_number in range (3):
# Out:
#   File "/tmp/ipykernel_617/1303268269.py", line 26
#
#     ^
# SyntaxError: incomplete input

# %%
! git --version
# Out:
# git version 2.34.1
